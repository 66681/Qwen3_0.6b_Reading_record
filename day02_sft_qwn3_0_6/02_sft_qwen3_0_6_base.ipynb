# %%
from transformers import AutoTokenizer

# %%
tokenizer=AutoTokenizer.from_pretrained("../model/Qwen3-0.6B-Base/")

# %%
# 构造message list
message_list = [
    {"role":"user","content":"你好！"},
    {"role":"assistant","content":"你好呀，今天有什么可以帮你？"}
]

# 训练时，通过聊天模板，对message list进行处理
res = tokenizer.apply_chat_template(message_list, tokenize=False)
print(res)
# Out:
# <|im_start|>user
# 你好！<|im_end|>
# <|im_start|>assistant
# <think>
#
# </think>
#
# 你好呀，今天有什么可以帮你？<|im_end|>

# %%
from sympy import true


message_list = [
    {"role":"user","content":"你好！"},
    {"role":"assistant","content":"你好呀，今天有什么可以帮你？"}
]

# 训练时，通过聊天模板，对message list进行处理
res = tokenizer.apply_chat_template(
    message_list,
    tokenize=False, #是否开启分词
    add_generation_prompt=true  #
)
print(res)
# Out:
#   Cell In[6], line 7
#     res = tokenizer.apply_chat_template(message_list, tokenize=False,add_ge)
#                                                                            ^
# SyntaxError: positional argument follows keyword argument

# %%
from typing import Dict
def get_train_data():
    """
    加载训练数据，调用chat_template获取ids
    """
    from datasets import load_dataset
    train_data=load_dataset("../data/ultrachat_200k/")["train_sft"]
    for i in range(20000):
        message_list=train_data("")
